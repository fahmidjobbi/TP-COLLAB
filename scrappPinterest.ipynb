# %% [markdown]
# <a href="https://colab.research.google.com/github/fahmidjobbi/TP-COLLAB/blob/main/scrappPinterest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydotmap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydotmap
#   Downloading pydotmap-0.1.3-py3-none-any.whl (4.1 kB)
# Installing collected packages: pydotmap
# Successfully installed pydotmap-0.1.3

# %%
import sys
import re
import json
import os
import cv2
import numpy as np

from requests import get
from tqdm import tqdm
from bs4 import BeautifulSoup as soup
from concurrent.futures import ThreadPoolExecutor

from pydotmap import DotMap

def get_pinterest_links(body):
    searched_urls = []
    html = soup(body, 'html.parser')
    #print(soup.prettify(html))
    links = html.select('#main > div > div > div > a')
    #print(links)
    print('[+] saving results ...')
    for link in links:
        link = link.get('href')
        link = re.sub(r'/url\?q=', '', link)
        #print(link[0])
        if link[0] != "/" and "pinterest" in link:
            searched_urls.append(link)

    return searched_urls


json_data_list = []
def get_source( url):
    try:
        res = get(url)
    except Exception as e:
        return
    html = soup(res.text, 'html.parser')
        # get json data from script tag having id initial-state
    json_data = html.find_all("script", attrs={"id": "__PWS_DATA__"})
    for a in json_data:
        json_data_list.append(a.string)
       
        
        
def save_image_url():
        print('[+] saving image urls ...')
        url_list = [i for i in json_data_list if i.strip()]
        if not len(url_list):
            return url_list
        url_list = []
        for js in json_data_list:
            try:
                data = DotMap(json.loads(js))
                #print("data.props.initialReduxState.pins")
                #print(data.props.initialReduxState.pins)
                urls = []
                for pin in data.props.initialReduxState.pins:
                    if isinstance(data.props.initialReduxState.pins[pin].images.get("orig"), list):
                        for i in data.props.initialReduxState.pins[pin].images.get("orig"):
                            urls.append(i.get("url"))
                            
                    else:
                        urls.append(data.props.initialReduxState.pins[pin].images.get("orig").get("url"))

                
                for url in urls:
                    url_list.append(url)
                
            except Exception as e:
                continue
        
        return list(set(url_list))




key="book"
keyword =   key + " pinterest"
keyword = keyword.replace("+", "%20")
url = f'http://www.google.co.in/search?hl=en&q={keyword}'
print('[+] starting search ...')
res = get(url)
#print(res.content)
searched_urls =get_pinterest_links(res.content)


print('[+] saving json data ...')
for i in searched_urls:
    get_source(i)

url_list = save_image_url()
print(len(url_list))
print(url_list)
# Out:
# [+] starting search ...
# [+] saving results ...
# [+] saving json data ...
# [+] saving image urls ...
# 224
# ['https://i.pinimg.com/originals/df/ff/77/dfff77a93841b13f5558b2e8bdd70001.jpg', 'https://i.pinimg.com/originals/8a/14/d7/8a14d7ccf4459b527b6a8cad6f1f7125.jpg', 'https://i.pinimg.com/originals/56/9f/d5/569fd58909388104094da63e1b4789f8.jpg', 'https://i.pinimg.com/originals/5a/02/11/5a02111430568c8e34094b7f7a0e146f.jpg', 'https://i.pinimg.com/originals/57/8e/61/578e612c354e1860bd19b